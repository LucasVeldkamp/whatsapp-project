# %%
from abc import ABC
from jinja2 import Template
from datetime import datetime
import uuid

from jinja2 import UndefinedError
import logging 
import copy

logging.basicConfig(format='%(asctime)s %(message)s',
                    filemode='w')
logger = logging.getLogger()
logger.setLevel(logging.ERROR)

days_of_the_week = {
    0: "Maandag",
    1: "Dinsdag",
    2: "Woensdag",
    3: "Donderdag",
    4: "Vrijdag",
    5: "Zaterdag",
    6: "Zondag"
}

months = {
    1: "Januari",
    2: "Februari",
    3: "Maart",
    4: "April",
    5: "Mei",
    6: "Juni",
    7: "Juli",
    8: "Augustus",
    9: "September",
    10: "Oktober",
    11: "November",
    12: "December",
}

class LatexSyntax:
    OPEN = '{'
    CLOSE = '}'
    BACKSLASH = chr(92)
    PERCENTAGE = "%"

class LatexCommands:
    BEGINFLUSHRIGHT = str(Template(
        """{{ latex.BACKSLASH }}begin{{ latex.OPEN }}flushright{{ latex.CLOSE }}""").render(latex=LatexSyntax()))
    ENDFLUSHRIGHT = str(Template(
        """{{ latex.BACKSLASH }}end{{ latex.OPEN }}flushright{{ latex.CLOSE }}""").render(latex=LatexSyntax()))
    BEGINCOLORBOX = str(Template(
        """{{ latex.BACKSLASH }}begin{{ latex.OPEN}}tcolorbox{{ latex.CLOSE }}""").render(latex=LatexSyntax()))
    ENDCOLORBOX = str(Template(
        """{{ latex.BACKSLASH }}end{{ latex.OPEN}}tcolorbox{{ latex.CLOSE }}""").render(latex=LatexSyntax()))

class LatexTemplates:
    DAY_SEGMENT = Template("""
    {{ latex.BACKSLASH }}begin{{ latex.OPEN }}center{{ latex.CLOSE }}
    {{ latex.BACKSLASH }}begin{{ latex.OPEN }}tcolorbox{{ latex.CLOSE }}[
        colback=whatsapplightblue, 
        colframe=whatsapplightblue, 
        width=3.0cm,
        arc=3mm, auto outer arc,
        halign=center,
        valign=center,
        ]
    {{ latex.BACKSLASH }}scriptsize  {{ message.metadata.day }} {{ message.metadata.date }}
    {{ latex.BACKSLASH }}end{{ latex.OPEN }}tcolorbox{{ latex.CLOSE }}
    {{ latex.BACKSLASH }}end{{ latex.OPEN }}center{{ latex.CLOSE }}
    """)

    MONTH_SEGMENT = Template("""
    {{ latex.BACKSLASH }}begin{{ latex.OPEN }}center{{ latex.CLOSE }}
    {{ latex.BACKSLASH }}begin{{ latex.OPEN }}tcolorbox{{ latex.CLOSE }}[
        colback=whatsapplightblue, 
        colframe=whatsapplightblue, 
        width=3.0cm,
        arc=3mm, auto outer arc,
        halign=center,
        valign=center,
        ]
    {{ latex.BACKSLASH }}normalsize  {{ message.metadata.month }}
    {{ latex.BACKSLASH }}end{{ latex.OPEN }}tcolorbox{{ latex.CLOSE }}
    {{ latex.BACKSLASH }}end{{ latex.OPEN }}center{{ latex.CLOSE }}
    """)

    NORMAL = Template("""      
    {% if message.metadata.person.perspective == True -%}
    {{ command.BEGINFLUSHRIGHT }}
    {% endif -%}
    {{ command.BEGINCOLORBOX }}[
        colback={{ message.metadata.colour }}, 
        colframe={{ message.metadata.colour }}, 
        width={{ message.metadata.width }}cm,
        arc=3mm, auto outer arc,
        halign=left,
        {% if message.metadata.person.name != message.previous_message_metadata.person.name -%}
        title = {{ latex.BACKSLASH }}color{{ latex.OPEN}}{{message.metadata.person.colour }}{{ latex.CLOSE }} {{ message.metadata.person.name }},
        {% endif -%}
        ]
    {{ latex.BACKSLASH}}footnotesize {{ message.text }}
        {{ command.BEGINFLUSHRIGHT }}
            {{ latex.BACKSLASH }}tiny {{ latex.BACKSLASH }}textbf{{ latex.OPEN }}{{ message.metadata.time}}{{ latex.CLOSE }} {{ latex.BACKSLASH }}par  
        {{ command.ENDFLUSHRIGHT }}
    {{ command.ENDCOLORBOX }}
    {% if message.metadata.person.perspective == True -%}
    {{ command.ENDFLUSHRIGHT }}
    {% endif -%}
        """)

    IMAGE = Template("""      
    {% if message.metadata.person.perspective == True -%}
    {{ command.BEGINFLUSHRIGHT }}
    {% endif -%}
    {{ command.BEGINCOLORBOX }}[
        colback={{ message.metadata.colour }}, 
        colframe={{ message.metadata.colour }}, 
        width=6.75cm,
        arc=3mm, auto outer arc,
        halign=left,
        {% if message.metadata.person.name != message.previous_message_metadata.person.name -%}
        title = {{ latex.BACKSLASH }}color{{ latex.OPEN}}{{message.metadata.person.colour }}{{ latex.CLOSE }} {{ message.metadata.person.name }},
        {% endif -%}
        ]

    {% if message.metadata.person.perspective == True -%}
    {{ command.BEGINFLUSHRIGHT }}
    {% endif -%}
        {{ latex.BACKSLASH }}begin{figure}[H]
        {{ latex.BACKSLASH }}includegraphics[width=5.75cm, right]{{ latex.OPEN}}{{ message.metadata.path}}{{ latex.CLOSE}}
        {{ latex.BACKSLASH }}end{figure}   
    {% if message.metadata.person.perspective == True -%}
    {{ command.ENDFLUSHRIGHT }}
    {% endif -%}    
    {{ command.BEGINFLUSHRIGHT }}
            {{ latex.BACKSLASH }}tiny {{ latex.BACKSLASH }}textbf{{ latex.OPEN }}{{ message.metadata.time}}{{ latex.CLOSE }} {{ latex.BACKSLASH }}par  
        {{ command.ENDFLUSHRIGHT }}
    {{ command.ENDCOLORBOX }}
    {% if message.metadata.person.perspective == True -%}
    {{ command.ENDFLUSHRIGHT}}
    {% endif -%}
        """)


class Person:
    def __init__(self, contact_name, name, colour, id, perspective=False):
        self = self
        self.contact_name = contact_name
        self.name = name
        self.colour = colour
        self.perspective = perspective
        self.id = id


class MessageMetaData:
    def __init(self):
        self.id = None
        self.message_type = None
        self.date = None
        self.time = None
        self.month = None
        self.day_of_week = None
        self.day = None
        self.name = None
        self.person = None
        self.colour = None
        self.width = None
        self.attachment_type = None
        self.first_message = None
        self.new_date = None
        self.new_month = None
        
    def get_metadata(self):
        return self


class Message(ABC):
    def __init__(self, message, id, persons, message_type, metadata, previous_message_metadata, group, current_date,current_month):
        self = self
        self.message = message
        self.persons = persons
        self.message_type = message_type
        self.metadata = metadata
        self.previous_message_metadata = previous_message_metadata
        self.group = group
        self.current_date = current_date
        self.current_month = current_month

    def exception_handler(self):
        if self.message == '[27-02-2022 12:32:28] ‎ +31617146903 Floris van gelder heeft de groep Floris & Tamara, LMS 56 gemaakt':
            raise Exception("Floris Jan")
        return self

    def get_date(self):
        self.date_start = self.message.find('[') + 1
        self.date_end = self.message.find(']')
        date_segment = self.message[self.date_start:self.date_end]
        self.metadata.date, self.metadata.time = date_segment.split(' ', 1)
        self.metadata.time = self.metadata.time[0:5]
        try:
            self.metadata.day_of_week = datetime.strptime(
                self.metadata.date, "%d-%m-%Y").weekday()
            self.metadata.month = datetime.strptime(
                self.metadata.date, "%d-%m-%Y").month
            self.metadata.month = months.get(self.metadata.month)
            self.metadata.day = days_of_the_week.get(self.metadata.day_of_week)

            if self.current_date == self.metadata.date:
                self.metadata.new_date = False
            else:
                self.metadata.new_date = True        
          
        except IndexError as error:
            logger.error(error,self.metadata.date)
        except AttributeError as error:
            logger.error(error,self.metadata.date)
        return self

    def get_new_date(self):
        try:
            if self.current_date == self.metadata.date:
                self.metadata.new_date = False
            else:
                self.metadata.new_date = True        
        except IndexError as error:
            logger.error(error,self.metadata.date)
        except AttributeError as error:
            logger.error(error,self.metadata.date)

        try:
            if self.current_month == self.metadata.month:
                self.metadata.new_month = False
            else:
                self.metadata.new_month = True        
        except IndexError as error:
            logger.error(error,self.metadata.date)
        except AttributeError as error:
            logger.error(error,self.metadata.date)
        return self

    def get_name(self):
        self.name_start = self.date_end
        self.name_end = self.message[self.name_start:].find(':')
        self.metadata.name = self.message[self.name_start +
                                          2:(self.name_start + self.name_end)]
        return self

    def get_person(self):
        try:
            self.metadata.person = [
                person for person in self.persons if person.contact_name == self.metadata.name][0]
        except IndexError:
            self.metadata.person = Person(name="Idioot", contact_name="Idioot",
               colour="Red", id=999, perspective=False)
        return self

    def get_message_colour(self):
        if self.metadata.person.perspective == True:
            self.metadata.colour = "whatsappgreen"
        else:
            self.metadata.colour = "whatsappgray"
        return self

    def get_message_width(self):
        self.metadata.width = sorted([3, int(len(self.text)) * 0.1, 9.5])[1]
        return self

    def get_print_name(self):
        try:
            if self.group:
                if self.previous_message_metadata.person.id is None:
                    self.metadata.print_name = False
                elif self.previous_message_metadata.person.id == self.metadata.person.id:
                    self.metadata.print_name = False
                else:
                    self.metadata.print_name = True
            else:
                self.metadata.print_name = False
        except AttributeError as error:
            logger.error(f"{error}")

        return self


class NormalMessage(Message):
    def get_message(self):
        self.text = self.message[(
            self.name_start + self.name_end + self.date_start)::]
        return self


class MessageWithoutSenderMetaData(Message):
    def get_message(self):
        self.text = self.message
        return self


class AttachmentMessage(Message):
    def get_attachment(self):
        attachment_start = self.message.find('<') + 1
        attachment_end = self.message.find('>')
        self.attachment = self.message[attachment_start:attachment_end]
        self.attachment = self.attachment.split(':', 1)
        self.attachment = self.attachment[1][1::]
        return self

    def get_attachment_type(self):
        try:
            self.metadata.attachment_type = self.attachment.split('.', 1)
            self.metadata.attachment_type = self.metadata.attachment_type[1]
        except IndexError as error:
            logger.error({error})
            self.metadata.attachment_type = "unknown"
        return self

    def get_message_width(self):
        self.metadata.width = 6
        return self

    def get_attachment_path(self, folder):
        if self.metadata.attachment_type == 'jpg':
            self.metadata.path = "chats/" + folder + '/' + self.attachment 
        return self


class ChatHistory:
    def __init__(self, chat_name: str, persons: list,folder:str, group: bool):
        self = self
        self.name = chat_name
        self.persons = persons
        self.group = group
        self.folder = folder
        self.last_message_metadata = MessageMetaData()
        self.current_date = None
        self.current_month = None

    def open_chat(self, path):
        self.chat = open(path, "r")
        return self

    def read_history(self):
        self.chat_history = []
        id = 0
        
        for messages in self.chat:
            metadata = MessageMetaData()
            if id == 0:
                self.chat_history.append(f"Skip message {id}")
                id += 1
                continue
                
            if len(messages) == 0:
                self.chat_history.append(f"Skip message {id}")
                id += 1
                continue
            
            if self.group:
                if id <4:
                    id += 1
                    print(messages)
                    continue
                
            if messages[0] == '\u200e':
                MessageWithAttachment = AttachmentMessage(message=messages, id=id, persons=self.persons, message_type='attachment',
                                                          metadata=metadata, previous_message_metadata=self.last_message_metadata, group=self.group, current_date = self.current_date, current_month = self.current_month)
                (
                    MessageWithAttachment
                    .exception_handler()
                    .get_date()
                    .get_new_date()
                    .get_name()
                    .get_attachment()
                    .get_attachment_type()
                    .get_person()
                    .get_attachment_path(folder = self.folder)
                    .get_message_colour()
                    .get_message_width()
                    .get_print_name()
                )
                self.chat_history.append(MessageWithAttachment)
                self.last_message_metadata = MessageWithAttachment.metadata
                self.current_date, self.current_month = MessageWithAttachment.metadata.date,MessageWithAttachment.metadata.month
                id += 1
            elif messages[0] != '[':
                MessageWithoutMetaData = MessageWithoutSenderMetaData(message=messages, id=id, persons=self.persons, message_type='no_sender', metadata=self.last_message_metadata.get_metadata(
                ), previous_message_metadata=self.last_message_metadata, group=self.group,current_date = self.current_date,current_month = self.current_month)
                (MessageWithoutMetaData
                 .exception_handler()
                 .get_message()
                 .get_message_width()
                 .get_print_name()
                 .get_new_date()
                 )
                self.chat_history.append(MessageWithoutMetaData)
                self.last_message_metadata = copy.deepcopy(MessageWithoutMetaData.metadata)
                self.current_date, self.current_month = MessageWithoutMetaData.metadata.date,MessageWithoutMetaData.metadata.month
                id += 1
            else:
                Message = NormalMessage(message=messages, id=id, persons=self.persons, message_type='normal',
                                        metadata=metadata, previous_message_metadata=self.last_message_metadata, group=self.group,current_date = self.current_date,current_month = self.current_month)
                (
                    Message
                    .exception_handler()
                    .get_date()
                    .get_new_date()
                    .get_name()
                    .get_message()
                    .get_person()
                    .get_message_colour()
                    .get_message_width()
                    .get_print_name()
                )
                self.chat_history.append(Message)
                self.last_message_metadata = copy.deepcopy(Message.metadata)
                self.current_date, self.current_month = Message.metadata.date,Message.metadata.month
                id += 1            
        return self


class LatexGenerator:
    def __init__(self, chat_history):
        self = self
        self.chat_history = chat_history

    def generate_latex(self):
        self.storage = []
        id = 0
        for message in self.chat_history.chat_history:
            if type(message) == str:
                continue
                
            try:
                if message.metadata.new_date:
                    if self.chat_history.chat_history[id-1].metadata.new_date:
                        continue
                    rendered_template = LatexTemplates.DAY_SEGMENT.render(
                        message=message,
                        latex=LatexSyntax(),
                        command=LatexCommands()
                    )
                    self.storage.append(rendered_template)

                if message.metadata.new_month:
                    if self.chat_history.chat_history[id-1].metadata.new_month:
                        continue
                    rendered_template = LatexTemplates.MONTH_SEGMENT.render(
                        message=message,
                        latex=LatexSyntax(),
                        command=LatexCommands()
                    )
                    self.storage.append(rendered_template)

                if message.message_type in ['normal', 'no_sender']:
                    if len(message.text) == 1:
                        continue
                    rendered_template = LatexTemplates.NORMAL.render(
                        message=message,
                        latex=LatexSyntax(),
                        command=LatexCommands()
                    )
                elif message.message_type == 'attachment':
                    if message.metadata.attachment_type == 'jpg':
                        rendered_template = LatexTemplates.IMAGE.render(
                            message=message,
                            latex=LatexSyntax(),
                            command=LatexCommands()
                        )
                else:
                    logger.error("Unknown behaviour")
                self.storage.append(rendered_template)
                id += 1
            except UndefinedError as error:
                logger.error(error) 
            except AttributeError as error:
                logger.error(error)
        return self

# %%
gerda = ChatHistory(
    chat_name="Chat Gerda",
    folder = "gerda",
    persons=[
        Person(name="Irma", contact_name="Irma",
               colour="RawSienna", id=1, perspective=False),
        Person(name="Gerda", contact_name="Gerda Versteegen",
               colour="NavyBlue", id=2, perspective=True)
    ], group=False
).open_chat(path="WhatsApp Chat - Gerda Versteegen/_chat.txt").read_history()

tamara = ChatHistory(
    chat_name="Chat Tamara",
    folder = "tamara",
    persons=[
        Person(name="Irma", contact_name="Irma",
               colour="RawSienna", id=1, perspective=False),
        Person(name="Tamara", contact_name="Tamara",
               colour="BurntOrange", id=2, perspective=True)
    ], group=False
).open_chat(path="WhatsApp Chat - Tamara/_chat.txt").read_history()

plony = ChatHistory(
    chat_name="Chat Plony",
    folder = "plony",
    persons=[
        Person(name="Irma", contact_name="Irma",
               colour="RawSienna", id=1, perspective=False),
        Person(name="Plony", contact_name="Plony Hendriks",
               colour="YellowGreen", id=2, perspective=True)
    ], group=False
).open_chat(path="WhatsApp Chat - Plony Hendriks/_chat.txt").read_history()

thea = ChatHistory(
    chat_name="Chat Thea",
    folder = "thea",
    persons=[
        Person(name="Irma", contact_name="Irma",
               colour="RawSienna", id=1, perspective=True),
        Person(name="Plony", contact_name="Plony Hendriks",
               colour="YellowGreen", id=2, perspective=False),
        Person(name="Tamara", contact_name="Tamara",
               colour="BurntOrange", id=3, perspective=False),
        Person(name="Gerda", contact_name="Gerda Versteegen",
               colour="NavyBlue", id=4, perspective=False),
        Person(name="Floris", contact_name="+31617146903 Floris van gelder",
               colour="Red", id=5, perspective=False),
       Person(name="Karin",contact_name="Karin Lommers",colour="Purple",id=6,perspective=False)
    ], group=True
).open_chat(path="WhatsApp Chat - Thea/_chat.txt").read_history()

generator = LatexGenerator(chat_history=gerda).generate_latex()

for test in generator.storage[0:100000]:
    print(test)
# Out:
# 2023-02-10 21:08:51,127 {IndexError('list index out of range')}
# 2023-02-10 21:08:51,177 {IndexError('list index out of range')}
# 2023-02-10 21:08:51,342 {IndexError('list index out of range')}
# 2023-02-10 21:08:51,541 {IndexError('list index out of range')}
# 2023-02-10 21:08:51,637 'MessageMetaData' object has no attribute 'person'
# [27-02-2022 12:32:28] ‎+31617146903 Floris van gelder heeft de groep Floris & Tamara, LMS 56 gemaakt
#
# [27-02-2022 12:32:28] ‎+31617146903 Floris van gelder heeft u toegevoegd
#
# [27-02-2022 14:16:43] Tamara: 🙋‍♀️
# 2023-02-10 21:08:52,246 'str' object has no attribute 'metadata'
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=6.300000000000001cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dank je wel voor je mail en je telefoonnummers. Ik sla ze op.
#
#         \begin{flushright}
#             \tiny \textbf{22:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Geen dank. Ik hoop dat je moeder weer snel fit is. Geef maar een seintje als het nog een keer nodig is
#
#         \begin{flushright}
#             \tiny \textbf{22:07} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Doe ik
#
#         \begin{flushright}
#             \tiny \textbf{22:17} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Zondag 27-06-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ha Irma, hoe gaat het met je Moeder. Ik zou haar wel een keer willen bellen, maar ik wil haar daar ook niet mee belasten. Misschien is de telefoon aanpakken nog te veel voor haar. Hoop dat ze weer aan de betere hand is. Doe haar in ieder geval de groeten van mij. Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{10:26} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Hallo Gerda, wat attent van je om te informeren. Ik had je eeder een update willen geven, maar wist niet goed wat.
#
#         \begin{flushright}
#             \tiny \textbf{13:42} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Er lijkt niet echt verbetering tot nu toe en morgen belt mijn moeder op mijn aandringen weer de HA. Even afwachten dus nog. Ze hoopt zelf dinsdag de boodschappen weer te kunnen doen en ik zal straks het geld voor de boodschappen overmaken.
#
#         \begin{flushright}
#             \tiny \textbf{13:42} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=4.7cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Fijne zondag. Groetjes en aai voor Bilan, Irma
#
#         \begin{flushright}
#             \tiny \textbf{13:42} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Wat vervelend, als je denkt dat ik dinsdag weer even de boodschappen voor haar moet halen, kun je nog wel even wachten met overmaken. Als je moeder te snel weer te veel doet, is ze misschien weer terug bij af. Doe haar de hartelijke groeten en wens haar beterschap!
#
#         \begin{flushright}
#             \tiny \textbf{13:47} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Beste Gerda, ik denk dat ik graag op je aanbod voor de boodschappen dinsdag in ga. Mijn moeder is nog niet zover, maar ik probeer haar morgen over te halen. Ze was heel blij met jouw groeten en beterschapswensen en groet jou terug.
#
#         \begin{flushright}
#             \tiny \textbf{17:22} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3.4000000000000004cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Dank voor je hulp. Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{17:22} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=4.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Ps. Dan wacht ik nog even met geld overmaken
#
#         \begin{flushright}
#             \tiny \textbf{17:22} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Maandag 28-06-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Hallo Gerda, zou je morgen bij de bakker een half volkoren (= al besteld) en bij de slager 2 maaltijden van 4 ons willen kopen. Een andijvie en een zuurkoolstamppot. Even zeggen dat het voor mw. Lommers is, dan bewaren ze het niet voor haar.
#
#         \begin{flushright}
#             \tiny \textbf{15:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Alvast heel erg bedankt.
#
#         \begin{flushright}
#             \tiny \textbf{15:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes,
#
#         \begin{flushright}
#             \tiny \textbf{15:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Irma
#
#         \begin{flushright}
#             \tiny \textbf{15:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=7.0cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Doe ik. Ik zal het een uur of 11 afgeven bij je moeder. Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{15:09} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Heel fijn dank je wel!
#
#         \begin{flushright}
#             \tiny \textbf{15:09} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Dinsdag 29-06-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ha Irma, ik heb de boodschappen gebracht. Je moeder was wel op, maar nog heel niet fit. Sterkte! Bel gerust als ik nog een boodschap moet doen. Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{11:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dank je wel. Ze wilde eigenlijk zelf vandaag al boodschappen doen. Ik heb deze keer heel erg aangedrongen.
#
#         \begin{flushright}
#             \tiny \textbf{11:07} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{11:07} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Zondag 04-07-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \normalsize  Juli
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Hallo Gerda,
#
#         \begin{flushright}
#             \tiny \textbf{13:46} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Mijn moeder is aan de beterende hand. Dinsdag gaat ze zelf weer boodschappen doen. Dank 🙏 voor je hulp. Het geld (€ 18,25) voor de boodschappen heb ik naar je rekening overgemaakt.
#
#         \begin{flushright}
#             \tiny \textbf{13:46} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Fijne zondag, groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{13:46} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Fijn dat ze weer opknapt, mocht het onverhoopt toch weer iets minder zijn, schroom niet om te vragen. Als je moeder donderdag voor de rondom nog hulp nodig heeft, kunnen Jos of ik wel helpen. Laat maar weten. Doe je moeder de groetjes, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{13:53} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Dinsdag 06-07-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Beste Gerda, op je aanbod voor hulp bij de rondom gaat mijn moeder graag in. Liever doet ze natuurlijk zelf, maar wat hulp is nu welkom.
#
#         \begin{flushright}
#             \tiny \textbf{18:54} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Oké, dan neem ik vóór donderdag middag even contact met haar op. Donderdagmorgen  wordt de Rondom geleverd. Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{19:04} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=7.0cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Fijn dank je wel ik heb het tegen haar gezegd, ik was net even langs
#
#         \begin{flushright}
#             \tiny \textbf{19:14} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Zaterdag 10-07-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ha Irma, zojuist met je moeder de 'Rondom de kerk' rondgebracht en gezellig met haar koffie gedronken en genoten van haar mooie levensverhalen! Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{13:34} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Hoi Gerda, dank je wel voor je hulp en de gezelligheid die je mijn moeder geeft. Heel fijn. Een mooi weekend wens ik jullie met Bilan toe.
#
#         \begin{flushright}
#             \tiny \textbf{13:39} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{13:39} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.0cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dank je wel voor je felicitatie wensen en het samen met haar boodschappen doen vandaag.
#
#         \begin{flushright}
#             \tiny \textbf{16:07} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3.4000000000000004cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Een heel fijn verjaardagscadeau.
#
#         \begin{flushright}
#             \tiny \textbf{16:07} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes,
#
#         \begin{flushright}
#             \tiny \textbf{16:07} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Irma
#
#         \begin{flushright}
#             \tiny \textbf{16:07} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Maandag 04-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \normalsize  Oktober
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Thea is helemaal blij met de uitnodiging voor vandaag (zelf kan ik niet komen vandaag). Ik wens jullie een mooie drrrie october.
#
#         \begin{flushright}
#             \tiny \textbf{10:34} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=7.2cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Dank je wel. Het wordt zeker weer gezellig. Ik zal je een foto sturen.
#
#         \begin{flushright}
#             \tiny \textbf{10:36} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Thea heeft veel last van haar rug en loopt moeilijk. Ze heeft me verzekerd dat ze morgen contact opneemt met HA. Ik weet het dus ook even niet, maar fijn dat ze afleiding heeft vandaag
#
#         \begin{flushright}
#             \tiny \textbf{11:18} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=8.1cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Er zijn zitplaatsen genoeg en als het nodig is, brengen we haar thuis. Groetjes
#
#         \begin{flushright}
#             \tiny \textbf{11:20} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dat weet ik, dank je wel.
#
#         \begin{flushright}
#             \tiny \textbf{11:21} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000032-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000033-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000034-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000035-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000036-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000037-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000038-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000038-PHOTO-2021-10-04-17-08-53.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{17:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=5.9cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  🤩 ik had er graag bij willen zijn. Geweldig. Dank je wel!
#
#         \begin{flushright}
#             \tiny \textbf{17:15} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Zondag 17-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Goedeavond Gerda, ik begreep dat je einde middag begin avond even bent langsgeweest. Was Thea heel blij mee. Zoals je gezien zult  hebben is het sinds 4 october er niet beter op geworden. Verschillende pijnstillers werken niet goed en de oorzaak van de pijn is ook nog niet gediagnosticeerd. Gelukkig komt er wel sinds dit weekend 2x per dag hulp. Fijn dat je even langs kwam.
#
#         \begin{flushright}
#             \tiny \textbf{20:27} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{20:27} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ha Irma, ja ik had na het eten, met Bilan even een rondje gelopen. Ik was benieuwd hoe het ging. Vorige week was ik snip verkouden (geen corona gelukkig), maar daarom wilde ik vorige week niet langs gaan. Thea vertelde ook nog dat jij haar vandaag naar Roomburgh had gebracht voor een bezoek aan haar vriendin. Voor het halen en brengen naar Roomburgh mag je mij ook gerust bellen hoor. Als jij daar helemaal voor uit Boskoop moet komen. Voor ons een kleine moeite. Je moeder vertelde ook dat je volgende week nog op vakantie gaat. Laat weten als ik een boodschap of iets anders voor haar kan doen. We doen het graag voor haar. Groetjes, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{20:39} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dank je wel voor je aanbod, heel lief van je. Zeker voor de koffieochtend op Roomburgh, ga ik je nog wel eens vragen. Ik ga niet meer weg met vakantie, want wil  haar gewoon niet alleen laten nu. Maar dat heb ik nog niet verteld.
#
#         \begin{flushright}
#             \tiny \textbf{20:47} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=5.1000000000000005cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Ben heel blij dat de hulp uiteindelijk gelukt is.
#
#         \begin{flushright}
#             \tiny \textbf{20:47} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{20:47} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Maandag 18-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Beste Gerda, Het looprek viel in de smaak, vindt ze heel fijn, heeft ze steun aan, bij staan.
#
#         \begin{flushright}
#             \tiny \textbf{18:58} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Om jou een huissleutel te geven vond ze een goed idee en die geeft ze je morgen zelf. Ook fijn dat je de “Rondom de Kerk wilt doen en Lydia te vragen voor hulp bij naar de mis gaan. De koffieochtend op het trefpunt is ze ook heel blij mee. Dank je wel😊
#
#         \begin{flushright}
#             \tiny \textbf{18:58} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  De boodschappen voor dinsdag. Bij Weydeland 1/2 volkoren en bij de slager twee maaltijden van 400 g elk, (andijviestamppot en zuurkoolstamppot), dit is al besteld bij de slager. Even zeggen dat het voor mevr. Lommers is, anders bewaart hij voor niets voor haar.
#
#         \begin{flushright}
#             \tiny \textbf{19:03} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=5.1000000000000005cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Graag ook 200 g rundergehakt, dit is niet besteld.
#
#         \begin{flushright}
#             \tiny \textbf{19:03} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Doe ik. Spreek jij je moeder nog? zeg haar dan maar dat ik morgen eind van de ochtend kom, want ik neem aan dat ze half 10 nog niet opgestart is en dan moet ik ook weer opschieten om 10 uur in Voorschoten te zijn. Sterkte met alles en ik zal Lydia benaderen. Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{19:14} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=5.0cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Ik bel haar straks nog even om dit te vertellen.
#
#         \begin{flushright}
#             \tiny \textbf{19:31} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Dinsdag 19-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Dag Irma, ik heb vanmiddag de boodschappen bij je moeder gebracht. De bonnetjes liggen onder de notenkraker. Totaal 9,75 euro. Ik heb met je moeder afgesproken, dat ik het jou door zou geven, zodat je het over kunt maken. Dat mag ook volgende week als ik weer iets voor haar haal. Ze zat nog na te genieten, omdat haar gymlerares haar vanmorgen had opgehaald om mee koffie te drinken bij de gym. Ik had er overigens niet aan gedacht dat ik a.s maandag met mijn zus naar een schoonzus in Friesland zou gaan. Ik heb het Thea verteld, maar hoefde geen vervanger te zoeken. Donderdag belt je moeder me, als ze de Rondom heeft gekregen. Zij zet dan de namen erop en ik breng ze rond. Het liefst doet ze dat zelf, maar dat zal nog wel niet lukken. We zien wel. Ik heb Lydia nog niet gesproken, dus dat wordt vervolgd... Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{15:40} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Goedeavond Gerda, dank voor het halen van de boodschappen en de update. Alvast een fijne dag in Friesland gewenst.
#
#         \begin{flushright}
#             \tiny \textbf{18:38} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes,
#
#         \begin{flushright}
#             \tiny \textbf{18:38} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Irma
#
#         \begin{flushright}
#             \tiny \textbf{18:38} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Donderdag 21-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ha Irma, zojuist heb ik je moeder aan de lijn gehad. Lydia begeleidt haar zaterdag naar de kerk. Je moeder vertelde dat ze vandaag de hele dag in het ziekenhuis was geweest. Ze was erg moe, maar wel blij om te weten dat het allemaal goed kan komen met fysiotherapie. En ze was zo blij, "Irma is zo'n schat, dat ze de hele dag met me mee is gegaan"... "en ze heeft mijn eten nog klaargemaakt, fantastisch!" Over de rondom hebben we afgesproken, dat als zij ze heeft gekregen, ze mij belt. Dan breng ik ze rond. Fijn dat er bij haar aan de pijn iets gedaan kan worden. Aan de motivatie van je moeder zal het niet liggen. Sterkte en we houden contact. Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{20:15} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Hoi Gerda, Inderdaad wel een “gunstige” diagnose. Je had ergens gelijk met je hernia, want het is waarschijnlijk een beknelde zenuw. Alleen niet een “klassieke” hernia. Ik was zo blij dat we vandaag op een open gevallen plek terecht konden de eigenlijk afspraak stond op 8 november. O ja, Thea wil jou wel graag een sleutel geven, maar dat is ze gisteren vergeten.
#
#         \begin{flushright}
#             \tiny \textbf{20:59} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Fijn dat ze zaterdag iig naar de kerk kan. Mocht het blijken handiger te zijn dat ze voor dat soort “uitjes” een rolstoel heeft dan ga ik daar achter aan.
#
#         \begin{flushright}
#             \tiny \textbf{20:59} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{20:59} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ja een rolstoel is misschien sowieso handig. Mocht Thea naar de fysiotherapeut toe moeten, dan is ze met de rolstoel ook even buiten. Maar misschien komt de fysio bij haar thuis? Mocht ze een keer weggebracht moeten worden, dan mag je mij (na maandag) gerust in laten vliegen hoor. Geen probleem.
#
#         \begin{flushright}
#             \tiny \textbf{21:10} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=5.800000000000001cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Het is de bedoeling dat de fysiotherapeut aan huis komt.
#
#         \begin{flushright}
#             \tiny \textbf{21:12} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{19:13} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dank voor je goede zorgen en de update. Bij de bakker staat een half volkoren, een Friese pof en een appel Victoria klaar. De bakker weet dst mijn moeder niet goed kan lopen en dat er dus iemand anders kan komen om op te halen.
#
#         \begin{flushright}
#             \tiny \textbf{19:54} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3.1cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Fijn dat je een sleutel hebt.
#
#         \begin{flushright}
#             \tiny \textbf{19:54} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{19:54} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=7.800000000000001cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Ha Gerda, wat fijn dat jij er was toen ik echt alleen even langs kon komen.
#
#         \begin{flushright}
#             \tiny \textbf{15:48} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Ik hoop morgen met Thea wat ik op papier gezet had doorzet nemen. Het helpt hoop ik om het overzicht te houden.
#
#         \begin{flushright}
#             \tiny \textbf{15:48} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  * doorzet = door te
#
#         \begin{flushright}
#             \tiny \textbf{16:03} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Maandag 25-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=7.0cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Beste Gerda, ik hoop dat je een fijne tijd in Friesland hebt gehad.
#
#         \begin{flushright}
#             \tiny \textbf{19:16} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Morgen hoeven bij de slager alleen de twee maaltijden opgehaald te worden. Thea heeft vandaag zelf al een half volkoren en gehakt gehaald.
#
#         \begin{flushright}
#             \tiny \textbf{19:16} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Dinsdag 26-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Dag Irma, bij de apotheek zeiden ze iid dat de baxter morgen wordt gebracht. Ik heb zojuist de maaltijden bij Nozeman gehaald en bij Thea gebracht. Het doosje van de baxter stond nog inde keuken met nog de medicijnen voor vandaag en morgen, dus ik denk dat dat toch goed is gegaan. Ik heb de pillendoos maar in mijn tas gelaten. Je moeder wordt opstinaat van al het geregel rond haar. Als ze weer even wat kan vertellen over iets anders dan haar 'kwaal', fleurt ze weer helemaal op. De fysio komt om kwart over 2, want degene die om 4 uur zou komen was ziek. Voor de boodschappen heb ik tot nu toe totaal 23,90 euro betaald. De bonnetjes liggen bij je moeder in het notenbakje. Zaterdag breng ik een visje en om 5 uur begeleid ik haar naar de kerk. Groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{14:25} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dank je wel voor de update, je goede zorgen en last but not least voor het aanvoelen en onderkennen van de stemming. Het is ook niet makkelijk. Groetjes, Irma
#
#         \begin{flushright}
#             \tiny \textbf{14:29} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Donderdag 28-10-2021
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.75cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#
#     \begin{flushright}
#     \begin{figure}[H]
#         \includegraphics[width=5.75cm, right]{chats/gerda/00000063-PHOTO-2021-10-28-18-03-51.jpg}
#         \end{figure}
#     \end{flushright}
#     \begin{flushright}
#             \tiny \textbf{18:03} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=8.200000000000001cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Ah fijn, vroeg me al af, loop nu bij haar thuis naar binnen met wat wasgoed enzo
#
#         \begin{flushright}
#             \tiny \textbf{18:09} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=5.2cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Als je ook nog zin hebt in soep? Ik heb nog genoeg
#
#         \begin{flushright}
#             \tiny \textbf{18:12} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Ik kom er aan
#
#         \begin{flushright}
#             \tiny \textbf{18:14} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=6.1000000000000005cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Als je haar niet gaat brengen geen probleem dan doe ik het😊
#
#         \begin{flushright}
#             \tiny \textbf{13:22} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
# ...
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Ach dat is lief. Ik heb haar gezegd dat ik vannacht niet kwam en ook BZ heeft dat tegen haar gezegd. Ook heeft ze gezegd (nog) geen officiële nachtzorg te willen. Ik kom morgen weer slapen. Moeilijk, maar ik trek het even niet. Bellen is lastig, maar ik kan i.i.g. zeggen dat ik morgen weer kom
#
#         \begin{flushright}
#             \tiny \textbf{17:47} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Oke, dan stuur ik een app als ik straks bij Thea ben. Ik heb beloofd te blijven tot BZ komt en vannacht om 12u om een hoekje te komen kijken
#
#         \begin{flushright}
#             \tiny \textbf{17:49} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Fijn
#
#         \begin{flushright}
#             \tiny \textbf{17:50} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ha Irma, ik ben nu bij Thea
#
#         \begin{flushright}
#             \tiny \textbf{18:37} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Nu bellen?
#
#         \begin{flushright}
#             \tiny \textbf{18:37} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Prima
#
#         \begin{flushright}
#             \tiny \textbf{18:38} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.9cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Ha Irma, ik stuur je zo een paar appjes die we naar Karin stuurden.
#
#         \begin{flushright}
#             \tiny \textbf{20:51} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Ha Karin, ik heb je moeder de foto laten en ik moet je schrijven dat Thea zo waardeerde om wat je buiten je werk altijd nog deed. Thea heeft altijd veel van jullie en Cees gehouden. Dag lieve Kieks, groetjes van mams (en Gerda)
#
#         \begin{flushright}
#             \tiny \textbf{20:53} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=8.1cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Thea is erg moe en slaapt veel, af en toe haalt ze dan weer een herinnering op.
#
#         \begin{flushright}
#             \tiny \textbf{20:54} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=7.0cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Nu zegt ze nog: jullie (jij en Irma) stonden altijd voor mams klaar.
#
#         \begin{flushright}
#             \tiny \textbf{20:54} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  🙏
#
#         \begin{flushright}
#             \tiny \textbf{21:13} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Zaterdag 26-11-2022
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Je moeder ligt lekker op het H/L bed, hoeft geen water. Ze is blij dat ze me weer even ziet. Ik vertrek weer, welterusten.
#
#         \begin{flushright}
#             \tiny \textbf{00:08} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3.6cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Fijn ik lig ook al bijna te slapen
#
#         \begin{flushright}
#             \tiny \textbf{00:10} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Kun je even bellen?
#
#         \begin{flushright}
#             \tiny \textbf{10:16} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Hallo Gerda, Siegfried, Milanne en Steven gaan zo naar Boskoop. De huisarts is geweest. Ik kan hem bellen als dat nodig is.
#
#         \begin{flushright}
#             \tiny \textbf{20:52} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Mocht je nog willen komen dan ben je van harte welkom. Ik weet alleen niet of het me lukt om te slapen dan.
#
#         \begin{flushright}
#             \tiny \textbf{20:52} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=8.3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Zal ik dan nu 3 uur gaan slapen en dan 12 uur naar jou kom? Of zal ik nu al komen
#
#         \begin{flushright}
#             \tiny \textbf{21:02} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Als jij dat kan nu 3 uur slapen, en dan om 12.00 uur komen dat zou fijn zijn. Blijf jij dan in de  kamer bij Thea?
#
#         \begin{flushright}
#             \tiny \textbf{21:04} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=6.1000000000000005cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ja, dat lukt mij wel. Kom ik 12 uur naar jullie toe. Tot zo
#
#         \begin{flushright}
#             \tiny \textbf{21:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  😘
#
#         \begin{flushright}
#             \tiny \textbf{21:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Dinsdag 29-11-2022
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Goedemorgen Gerda, hoe gaat het met je? Moeilijk hè. Ondanks dat je weet dat dit eraan zit te komen. Ik vond het heel fijn om de laatste nacht van mijn moeder samen met jou bij haar te zijn. Heel bijzonder vond ik het. Ik app je nu voor het adres van Cathelijne, dat kan ik niet vinden. Heb jij dat toevallig?
#
#         \begin{flushright}
#             \tiny \textbf{10:06} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Wil je graag nog even naar Thea toe? Vanmiddag vanaf een uur of twee ben ik/zijn wij er denk ik wel.
#
#         \begin{flushright}
#             \tiny \textbf{10:09} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ik ga op zoek naar het adres. Ik kom graag vanmiddag even langs bij Thea, dan kan ik ook de tekst die ik had gemaakt voor de uitvaart even aan jullie laten horen/zien
#
#         \begin{flushright}
#             \tiny \textbf{11:00} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize  Hierbij:
#
#         \begin{flushright}
#             \tiny \textbf{13:20} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Cathalijne Louwes,
#
#         \begin{flushright}
#             \tiny \textbf{13:20} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize de Ridderstraat 5, 2313DN, Leiden.
#
#         \begin{flushright}
#             \tiny \textbf{13:20} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         ]
#     \footnotesize Groetjes, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{13:20} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Dank je wel
#
#         \begin{flushright}
#             \tiny \textbf{13:59} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=8.200000000000001cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Geen dank, hoe laat zal ik even komen? Laat maar weten wanneer het jullie schikt
#
#         \begin{flushright}
#             \tiny \textbf{14:03} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  Ik ben er nu alleen. Karin en ik lopen volgens mij langs elkaar heen met onze afspraken met jou. Je bent iig van harte welkom
#
#         \begin{flushright}
#             \tiny \textbf{14:37} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=3.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Dan kom ik er nu even aan, tot zo
#
#         \begin{flushright}
#             \tiny \textbf{14:53} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
#
#
#     \begin{tcolorbox}[
#         colback=whatsappgray,
#         colframe=whatsappgray,
#         width=3cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{RawSienna} Irma,
#         ]
#     \footnotesize  👍
#
#         \begin{flushright}
#             \tiny \textbf{14:53} \par
#         \end{flushright}
#     \end{tcolorbox}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \scriptsize  Woensdag 07-12-2022
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{center}
#     \begin{tcolorbox}[
#         colback=whatsapplightblue,
#         colframe=whatsapplightblue,
#         width=3.0cm,
#         arc=3mm, auto outer arc,
#         halign=center,
#         valign=center,
#         ]
#     \normalsize  December
#     \end{tcolorbox}
#     \end{center}
#
#
#     \begin{flushright}
#     \begin{tcolorbox}[
#         colback=whatsappgreen,
#         colframe=whatsappgreen,
#         width=9.5cm,
#         arc=3mm, auto outer arc,
#         halign=left,
#         title = \color{NavyBlue} Gerda,
#         ]
#     \footnotesize  Ha Irma, hoe gaat het? Kun je op school de draad weer een beetje oppakken? Ik moet zeggen dat ik weer goed slaap, ook omdat Jones mij snachts niet meer wakker piept. Maar ongemerkt kon ik met Thea in mijn gedachte, de slaap ook minder snel weer vatten.... Lieve groet, Gerda
#
#         \begin{flushright}
#             \tiny \textbf{13:05} \par
#         \end{flushright}
#     \end{tcolorbox}
#     \end{flushright}
